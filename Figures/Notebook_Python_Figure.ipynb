# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text

# %%
# Setting the desired Seaborn theme
sns.set_theme(
    context="paper",
    style='ticks',
    palette='colorblind',
    font='monospace',
    font_scale=1.2,
    rc={
        "figure.figsize": (12, 8),
        "axes.titlesize": "large",
        "axes.labelsize": "medium",
        "xtick.labelsize": "small",
        "ytick.labelsize": "small",
        "legend.fontsize": "medium",
    }
    
    )

# %% [markdown]
# # $\beta$ delta_EF vs. EF Plots

# %%
mydata = pd.read_csv("MG_diff_coefficients_and_EF.csv")
mydata
# Out:
#            Country Abbreviation  delta_Lnlabor_stock  delta_Lncapital_stock  \
# 0          Austria          AUT             0.167694               2.736604
# 1          Belgium          BEL            -2.262202              -2.401243
# 2         Bulgaria          BGR             0.316151              -1.380173
# 3          Croatia          HRV             0.058626              -2.029624
# 4           Cyprus          CYP            -0.118367               0.805607
# 5   Czech Republic          CZE            -0.076882               5.068162
# 6          Denmark          DNK            -0.322353              -1.980076
# 7          Estonia          EST             0.181673               0.475391
# 8          Finland          FIN            -1.265483               8.513349
# 9           France          FRA             1.022482               0.425346
# 10         Germany          DEU             0.796708              -5.526173
# 11          Greece          GRC             1.150020              -1.065278
# 12         Hungary          HUN             0.486519               0.587488
# 13         Iceland          ISL             0.654692              -5.905568
# 14         Ireland          IRL             0.830274               1.059422
# 15           Italy          ITA             0.261960               0.033834
# 16          Latvia          LVA             0.194095               1.583162
# 17       Lithuania          LTU            -0.087911              -4.847988
# 18      Luxembourg          LUX             1.067722              -1.478507
# 19           Malta          MLT             0.292534               2.145920
# 20     Netherlands          NLD            -1.105722              -0.355861
# 21          Norway          NOR            -2.598868              11.639902
# 22          Poland          POL            -0.264561               2.628233
# 23        Portugal          PRT             1.001511              -0.096080
# 24         Romania          ROU            -0.141584               1.581721
# 25        Slovakia          SVK             0.150220               0.885058
# 26        Slovenia          SVN             0.339475               3.146412
# 27           Spain          ESP             1.313490              -1.351530
# 28          Sweden          SWE             1.686375              -4.583236
# 29     Switzerland          CHE             1.310867              -0.055765
#
#     delta_RL  delta_GS  delta_RE  delta_MO         RL         GS         RE  \
# 0  -0.004804  0.006224 -0.001268  0.003585  77.633333  53.500000  75.033333
# 1  -0.000554  0.000076 -0.005902  0.000109  71.800000  45.233333  71.733333
# 2  -0.001058 -0.004065 -0.001073  0.000594  46.500000  84.300000  73.033333
# 3   0.001955 -0.001933 -0.006137 -0.005887  49.166667  61.733333  61.066667
# 4   0.001488  0.005043  0.007173  0.013055  54.966667  70.133333  73.466667
# 5  -0.007473 -0.002023  0.003641  0.009587  58.166667  77.433333  77.333333
# 6  -0.002088  0.000392 -0.003562 -0.003314  83.266667  51.033333  87.066667
# 7   0.004618  0.003756 -0.007026  0.008448  76.866667  76.933333  70.700000
# 8  -0.011948  0.001449  0.001725  0.001256  87.766667  53.466667  74.833333
# 9   0.001201 -0.001195 -0.002785 -0.003203  72.166667  39.066667  68.500000
# 10 -0.001455  0.000124 -0.004571  0.006365  78.866667  64.966667  71.333333
# 11  0.000153  0.001024 -0.004193  0.001434  46.533333  53.800000  68.566667
# 12  0.004173 -0.001374 -0.003672  0.005258  47.133333  65.100000  69.200000
# 13 -0.010850  0.005238 -0.010177  0.013437  78.333333  71.133333  78.066667
# 14 -0.012921  0.009825 -0.009725 -0.006027  77.400000  80.900000  81.800000
# 15 -0.002477  0.002418 -0.005286  0.000157  55.066667  51.133333  68.933333
# 16 -0.002103  0.001987 -0.000133 -0.004420  50.400000  77.000000  77.300000
# 17 -0.012549  0.013978 -0.005124 -0.004964  60.866667  82.933333  74.466667
# 18 -0.001073  0.009073 -0.014080  0.006318  80.400000  70.300000  65.766667
# 19 -0.003516 -0.002841 -0.001638 -0.009748  56.833333  71.600000  68.866667
# 20 -0.001532 -0.001046  0.001564  0.000499  83.933333  62.600000  75.233333
# 21  0.013781 -0.023734 -0.008182  0.029997  86.533333  60.000000  72.833333
# 22  0.000252 -0.000594  0.000750 -0.001171  52.033333  70.033333  70.466667
# 23 -0.006151  0.000192 -0.004076 -0.005416  65.100000  55.100000  69.000000
# 24  0.000424 -0.002668  0.011223 -0.006240  52.800000  82.666667  70.100000
# 25  0.001334  0.003276 -0.008112 -0.004070  47.800000  70.633333  64.433333
# 26  0.002727  0.001637 -0.005787 -0.006771  58.833333  59.766667  74.700000
# 27  0.001137 -0.003698  0.008411 -0.000602  58.733333  53.200000  70.700000
# 28 -0.003370  0.000709 -0.001549  0.000509  87.166667  55.500000  74.633333
# 29 -0.012489 -0.002443  0.010562  0.002146  85.100000  77.200000  77.700000
#
#            MO
# 0   82.000000
# 1   80.333333
# 2   72.000000
# 3   73.666667
# 4   73.666667
# 5   82.000000
# 6   85.333333
# 7   82.000000
# 8   83.666667
# 9   75.333333
# 10  78.666667
# 11  62.000000
# 12  78.666667
# 13  80.666667
# 14  82.000000
# 15  73.666667
# 16  77.000000
# 17  78.666667
# 18  87.000000
# 19  77.000000
# 20  85.333333
# 21  72.733333
# 22  78.666667
# 23  72.000000
# 24  68.666667
# 25  77.000000
# 26  68.666667
# 27  80.333333
# 28  83.666667
# 29  87.466667

# %%
# Convert columns to numeric, forcing errors to NaN to handle mixed types
mydata['RL'] = pd.to_numeric(mydata['RL'], errors='coerce')
mydata['GS'] = pd.to_numeric(mydata['GS'], errors='coerce')
mydata['RE'] = pd.to_numeric(mydata['RE'], errors='coerce')
mydata['MO'] = pd.to_numeric(mydata['MO'], errors='coerce')

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                30 non-null     object
#  1   Abbreviation           30 non-null     object
#  2   delta_Lnlabor_stock    30 non-null     float64
#  3   delta_Lncapital_stock  30 non-null     float64
#  4   delta_RL               30 non-null     float64
#  5   delta_GS               30 non-null     float64
#  6   delta_RE               30 non-null     float64
#  7   delta_MO               30 non-null     float64
#  8   RL                     30 non-null     float64
#  9   GS                     30 non-null     float64
#  10  RE                     30 non-null     float64
#  11  MO                     30 non-null     float64
# dtypes: float64(10), object(2)
# memory usage: 2.9+ KB

# %%
mydata['Abbreviation']
# Out:
# 0     AUT
# 1     BEL
# 2     BGR
# 3     HRV
# 4     CYP
# 5     CZE
# 6     DNK
# 7     EST
# 8     FIN
# 9     FRA
# 10    DEU
# 11    GRC
# 12    HUN
# 13    ISL
# 14    IRL
# 15    ITA
# 16    LVA
# 17    LTU
# 18    LUX
# 19    MLT
# 20    NLD
# 21    NOR
# 22    POL
# 23    PRT
# 24    ROU
# 25    SVK
# 26    SVN
# 27    ESP
# 28    SWE
# 29    CHE
# Name: Abbreviation, dtype: object

# %%
# Set up a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(20, 20))

# Function to create the plot and add text annotations
def create_plot(ax, x, y, xlabel, ylabel, title):
    sns.regplot(x=x, y=y, data=mydata, ax=ax, color='lightgray', marker='.', lowess=True)
    sns.regplot(x=x, y=y, data=mydata, ax=ax, color='black', marker='.' , ci=False , line_kws={'alpha':0.3})
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    texts = [text(row[x] + 0.2, row[y], row['Abbreviation'], horizontalalignment='center', verticalalignment='bottom', size='small', color='black', weight='normal') 
             for idx, row in mydata.iterrows()]
    adjust_text(texts, ax=ax, arrowprops=dict(arrowstyle="->", color='black', lw=0.5))

# RL vs delta_RL
create_plot(axs[0, 0], 'RL', 'delta_RL', r'$RL$', r'$\beta_{3,i}$', r'$RL$ vs $\beta_{3,i}$')

# GS vs delta_GS
create_plot(axs[0, 1], 'GS', 'delta_GS', r'$GS$', r'$\beta_{4,i}$', r'$GS$ vs $\beta_{4,i}$')

# RE vs delta_RE
create_plot(axs[1, 0], 'RE', 'delta_RE', r'$RE$', r'$\beta_{5,i}$', r'$RE$ vs $\beta_{5,i}$')

# MO vs delta_MO
create_plot(axs[1, 1], 'MO', 'delta_MO', r'$MO$', r'$\beta_{6,i}$', r'$MO$ vs $\beta_{6,i}$')

plt.tight_layout()
plt.show()

# %%
# Function to create the plot and add text annotations
def create_plot(ax, x, y, xlabel, ylabel, title):
    sns.regplot(x=x, y=y, data=mydata, ax=ax, color='lightgray', marker='.', lowess=True)
    sns.regplot(x=x, y=y, data=mydata, ax=ax, color='black', marker='.' , ci=False , line_kws={'alpha':0.3})
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    texts = [ax.text(row[x] + 0.2, row[y], row['Abbreviation'], horizontalalignment='center', verticalalignment='bottom', size='small', color='black', weight='normal') 
             for idx, row in mydata.iterrows()]
    adjust_text(texts, ax=ax, arrowprops=dict(arrowstyle="->", color='black', lw=0.5))

# Plot RL vs delta_RL
plt.figure(figsize=(10, 8))
create_plot(plt.gca(), 'RL', 'delta_RL', r'$RL$', r'$\beta_{3,i}$', r'$RL$ vs $\beta_{3,i}$')
plt.show()

# Plot GS vs delta_GS
plt.figure(figsize=(10, 8))
create_plot(plt.gca(), 'GS', 'delta_GS', r'$GS$', r'$\beta_{4,i}$', r'$GS$ vs $\beta_{4,i}$')
plt.show()

# Plot RE vs delta_RE
plt.figure(figsize=(10, 8))
create_plot(plt.gca(), 'RE', 'delta_RE', r'$RE$', r'$\beta_{5,i}$', r'$RE$ vs $\beta_{5,i}$')
plt.show()

# Plot MO vs delta_MO
plt.figure(figsize=(10, 8))
create_plot(plt.gca(), 'MO', 'delta_MO', r'$MO$', r'$\beta_{6,i}$', r'$MO$ vs $\beta_{6,i}$')
plt.show()

# %% [markdown]
# ---
# # Making the QQ Plots B&W

# %%
from matplotlib import image as mpimg

# %%
# Load the image
img1 = mpimg.imread('Pooled_qqplot_color.png')
img2 = mpimg.imread('FE_diff_qqplot_color.png')
img3 = mpimg.imread('CCEMG_diff_qqplot_color.png')

# %%
# Convert to grayscale
bw1 = np.dot(img1[...,:3] , [0.2989,0.5870,0.1140])
bw2 = np.dot(img2[...,:3] , [0.2989,0.5870,0.1140])
bw3 = np.dot(img3[...,:3] , [0.2989,0.5870,0.1140])

# %%
# Save the images
plt.imsave('Pooled_qqplot.png' , bw1 , cmap='gray')
plt.imsave('FE_diff_qqplot.png' , bw2 , cmap='gray')
plt.imsave('CCEMG_diff_qqplot.png' , bw3 , cmap='gray')
