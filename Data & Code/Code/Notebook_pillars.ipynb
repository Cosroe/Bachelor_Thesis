# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('complete.csv')

# %%
df.head()
# Out:
#    Index  country  year         rgdpe         rgdpo       emp          avh  \
# 0      0  Austria  2000  314579.68750  306927.56250  3.759931  1798.432211
# 1      1  Austria  2001  308449.03125  299963.12500  3.785839  1785.420148
# 2      2  Austria  2002  313331.15625  306288.46875  3.780694  1782.847940
# 3      3  Austria  2003  318809.15625  313908.28125  3.806159  1773.977855
# 4      4  Austria  2004  330761.75000  326475.03125  3.825346  1776.465838
#
#          hc   labor_stock         rnna  ...  Market openness  Year Countries  \
# 0  3.117029  21077.292719  1870413.500  ...        74.333333  2000   Austria
# 1  3.133231  21178.488353  1918997.000  ...        72.666667  2001   Austria
# 2  3.149517  21229.009791  1960784.375  ...        73.200000  2002   Austria
# 3  3.165887  21376.199508  2005640.750  ...        73.800000  2003   Austria
# 4  3.182343  21625.917573  2049323.250  ...        73.266667  2004   Austria
#
# ...

# %%
df.isna().sum()
# Out:
# Index                                                            0
# country                                                          0
# year                                                             0
# rgdpe                                                            0
# rgdpo                                                            0
# emp                                                              0
# avh                                                              0
# hc                                                               0
# labor_stock                                                      0
# rnna                                                             0
# delta                                                            0
# capital_stock                                                    0
# Name                                                             0
# Index Year                                                       0
# ...

# %%
df.isna().sum()
# Out:
# Index                                                            0
# country                                                          0
# year                                                             0
# rgdpe                                                            0
# rgdpo                                                            0
# emp                                                              0
# avh                                                              0
# hc                                                               0
# labor_stock                                                      0
# rnna                                                             0
# delta                                                            0
# capital_stock                                                    0
# Name                                                             0
# Index Year                                                       0
# ...

# %%
df['Government size'] = df[['Tax Burden', 'Government Spending', 'Fiscal Health']].mean(axis=1, skipna=True)

# %%
df.isna().sum()
# Out:
# Index                                                            0
# country                                                          0
# year                                                             0
# rgdpe                                                            0
# rgdpo                                                            0
# emp                                                              0
# avh                                                              0
# hc                                                               0
# labor_stock                                                      0
# rnna                                                             0
# delta                                                            0
# capital_stock                                                    0
# Name                                                             0
# Index Year                                                       0
# ...

# %%
df['Regulatory efficiency'] = df[['Business Freedom', 'Labor Freedom', 'Monetary Freedom']].mean(axis=1, skipna=True)

# %%
df.isna().sum()
# Out:
# Index                                                            0
# country                                                          0
# year                                                             0
# rgdpe                                                            0
# rgdpo                                                            0
# emp                                                              0
# avh                                                              0
# hc                                                               0
# labor_stock                                                      0
# rnna                                                             0
# delta                                                            0
# capital_stock                                                    0
# Name                                                             0
# Index Year                                                       0
# ...

# %%
df['Market openness'] = df[['Trade Freedom', 'Investment Freedom', 'Financial Freedom']].mean(axis=1, skipna=True)

# %%
df.isna().sum()
# Out:
# Index                                                            0
# country                                                          0
# year                                                             0
# rgdpe                                                            0
# rgdpo                                                            0
# emp                                                              0
# avh                                                              0
# hc                                                               0
# labor_stock                                                      0
# rnna                                                             0
# delta                                                            0
# capital_stock                                                    0
# Name                                                             0
# Index Year                                                       0
# ...

# %%
df.dtypes
# Out:
# Index                                                            int64
# country                                                         object
# year                                                             int64
# rgdpe                                                          float64
# rgdpo                                                          float64
# emp                                                            float64
# avh                                                            float64
# hc                                                             float64
# labor_stock                                                    float64
# rnna                                                           float64
# delta                                                          float64
# capital_stock                                                  float64
# Name                                                            object
# ...

# %%
df.to_csv('Completed.csv')
